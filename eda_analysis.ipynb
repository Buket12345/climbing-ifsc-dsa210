# %%
import matplotlib.pyplot as plt
import seaborn as sns
github_link = "https://raw.githubusercontent.com/Buket12345/climbing-ifsc-dsa210/main"
import pandas as pd

df = pd.read_csv(f"{github_link}/final_dataset.csv")
print(df.shape)
df.head()
# Out:
# (126441, 18)
#    athlete_id  rank discipline  season        date  event_id  event_location  \
# 0          14     1       lead    2022  2022-07-09      1280         Villars
# 1          14     1       lead    2022  2022-06-22      1277       Innsbruck
# 2          14     1       lead    2022  2022-05-26      1278  Salt Lake City
# 3          14     2       lead    2021  2021-10-11      1224   United States
# 4          14     3       lead    2021  2021-09-17      1225          Moscow
#
#    d_cat  firstname lastname   age gender country  height  arm_span  \
# 0    585  Korbinian   FRANCK  35.0   male     DEU     NaN       NaN
# 1    585  Korbinian   FRANCK  35.0   male     DEU     NaN       NaN
# 2    585  Korbinian   FRANCK  35.0   male     DEU     NaN       NaN
# 3    585  Korbinian   FRANCK  35.0   male     DEU     NaN       NaN
# 4    585  Korbinian   FRANCK  35.0   male     DEU     NaN       NaN
#
#                   paraclimbing_sport_class    birthday  gdp_per_capita
# 0  Limited Range, Power & Stability 1: RP1  1989-09-02       63353.940
# 1  Limited Range, Power & Stability 1: RP1  1989-09-02       63353.940
# 2  Limited Range, Power & Stability 1: RP1  1989-09-02       63353.940
# 3  Limited Range, Power & Stability 1: RP1  1989-09-02       62950.047
# 4  Limited Range, Power & Stability 1: RP1  1989-09-02       62950.047

# %%
df.info()

df[['rank', 'gdp_per_capita', 'age', 'height']].describe()

print("Number of unique countries:", df['country'].nunique())
print("Season range:", df['season'].min(), "-", df['season'].max())
print("Disciplines:", df['discipline'].unique())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126441 entries, 0 to 126440
# Data columns (total 18 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   athlete_id                126441 non-null  int64
#  1   rank                      126441 non-null  int64
#  2   discipline                126441 non-null  object
#  3   season                    126441 non-null  int64
#  4   date                      126441 non-null  object
#  5   event_id                  126441 non-null  int64
#  6   event_location            125684 non-null  object
#  7   d_cat                     126441 non-null  int64
#  8   firstname                 126441 non-null  object
#  9   lastname                  126441 non-null  object
#  10  age                       84796 non-null   float64
#  11  gender                    126441 non-null  object
#  12  country                   126441 non-null  object
#  13  height                    23695 non-null   float64
#  14  arm_span                  6242 non-null    float64
#  15  paraclimbing_sport_class  1857 non-null    object
#  16  birthday                  84796 non-null   object
#  17  gdp_per_capita            126441 non-null  float64
# dtypes: float64(4), int64(5), object(9)
# memory usage: 17.4+ MB
# Number of unique countries: 84
# Season range: 1991 - 2023
# Disciplines: ['lead' 'boulder' 'speed' 'combined' 'boulder&lead']
